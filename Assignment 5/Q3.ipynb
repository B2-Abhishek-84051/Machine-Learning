# %% [markdown]
# ### Que. 3
# In the given dataset TVMarketing.csv you have given  sales based on 'TV' marketing budget.
# Build a linear regression model to predict 'Sales' using 'TV' as the predictor variable. Also plot regression line.
#
# Dataset : TVMarketing.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./TvMarketing.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
df.head(10)
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9
# 5    8.7    7.2
# 6   57.5   11.8
# 7  120.2   13.2
# 8    8.6    4.8
# 9  199.8   10.6

# %%
df.corr()
# Out:
#              TV     Sales
# TV     1.000000  0.782224
# Sales  0.782224  1.000000

# %%
df.cov()
# Out:
#                 TV       Sales
# TV     7370.949893  350.390195
# Sales   350.390195   27.221853

# %%
x = df.drop('Sales', axis=1)
y = df['Sales']

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
mean_values = np.ones(y.size) * y.mean()
mean_values
# Out:
# array([14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
#        14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225, 14.0225,
# ...

# %%
# show the observed values
plt.scatter(x['TV'], y, label='Observed Values', color="green") 

# draw mean line
mean_values = np.ones(y.size) * y.mean()
plt.plot(x['TV'], mean_values, color='red')
plt.scatter(x['TV'], mean_values, color='red', label="mean values")

# draw the regression line
plt.plot(x['TV'], model.predict(x), color='blue')
plt.scatter(x['TV'], model.predict(x), color='blue', label="expected values")


# title
plt.title('Regression Line graph')
plt.xlabel('TV')
plt.ylabel('Sales')

plt.legend()
